# %%
import struct
import zlib

f = open('example.png', 'rb')

# %%
PngSignature = b'\x89PNG\r\n\x1a\n'
if f.read(len(PngSignature)) != PngSignature:
    raise Exception('Invalid PNG Signature')

# %%
def read_chunk(f):
    # Returns (chunk_type, chunk_data)
    chunk_length, chunk_type = struct.unpack('>I4s', f.read(8))
    chunk_data = f.read(chunk_length)
    checksum = zlib.crc32(chunk_data, zlib.crc32(struct.pack('>4s', chunk_type)))
    chunk_crc, = struct.unpack('>I', f.read(4))
    if chunk_crc != checksum:
        raise Exception('chunk checksum failed {} != {}'.format(chunk_crc,
            checksum))
    return chunk_type, chunk_data

# %%
chunks = []
while True:
    chunk_type, chunk_data = read_chunk(f)
    chunks.append((chunk_type, chunk_data))
    if chunk_type == b'IEND':
        break

# %%
print([chunk_type for chunk_type, chunk_data in chunks])
# Out:
# [b'IHDR', b'sRGB', b'IDAT', b'IEND']

# %%
_, IHDR_data = chunks[0] # IHDR is always first chunk
width, height, bitd, colort, compm, filterm, interlacem = struct.unpack('>IIBBBBB', IHDR_data)

# %%
width, height
# Out:
# (233, 70)

# %%
IDAT_data = b''.join(chunk_data for chunk_type, chunk_data in chunks if chunk_type == b'IDAT')
IDAT_data
# Out:
# b'x\x9c\xed\x9dw\\SW\x1b\xc7\x9f\x10fX\xe2@\x91\x19D\x01\x192\x15D\x05\xda\xa2Xw](\x14\x17\xa2\xd5*\xb6\xb5\xbe~l\xdf\xb7\xed[\xeb\xa8\xa3\xf5U\xebVTp\x81{\xe2D\x84\x80\x82"C\x99\xb2E\x90\x91\x9d\x90q\xef}\xff\x08M\xa9\x04\x8c!\x10o=\xdf\x0f\x7f\xdc{\x9e\xe7\x9c\xe79\xc9/g\xe4\xdc|\xa0\x10\x04\x01\x08\x04\t\xd1\xd2t\x02\x08\x84\x8a \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\n\xd2.\x82\xac \xed"\xc8\x8a\xb6\xa6\x13@\xfc\x8d\xb8\xf8S\x17/_\xab\xac\xac\x1adO_\xfd\xf5JooO\xe5\xebfe=\xf9u\xdb\x0e\n\x00\x8b\xc5\x9e1}j\xd4\xa2y\x14\n\xa5;\x93\xd54\x04\xe2\xbd\xe1\xe4\xa9\x84]\xbb\xf7\x11\x04\xd1\xd2\xd2\xb2h\xf1r\xc7\xa1^y\xf9\xcf\x95\xac\xdb\xd8\xd84\xc2?\xb8\xb8\xa4\x94 \x88\xd4\xb4t\xba\x83\xeb\xfe\x03G\xba9_\r\xd3\xd3k\x86\xaa\xaa\xea\xa4\x9bwz8(\x00\x14\x15\x95\xdcKN\xe9\xf9\xb8\xef\xc4\xa93g\xaf^O\xc20\\OO\xef\xdf\xdf\xad\x11\x8b\xc5\x07\x0e\xc6*Y\xb7\xb8\xa4\xf4uC\xc3\xa9S\x89\x00\xe08d0\x00\xdc\xbes\xaf\x9b\xf3\xd50=\xaa\xdd\x86\x86\xc6\x88\xc8(\x8b\x01\xfd{2\xa8\x0ckk\xcb\r\x1b\xb7^\xbfq\xb3\xe7C+\x8f\x89\xb1qCC#\x86I\x01\xc0\xd6\xd6FGG\xa7\xa0\xa0P\xc9\xba>\xde\x9e?\xfd\xb0n\xfe\xfc\x08\x00(..\x05\x00gg\xc7n\xceW\xd3\xa8w\x18/+\xab\xf8|\xde\xe2\x801!s#\x16\xe6?\xfb\xdb|\'\x91Hf\x86E\x1e:rL\xbd\x11\x95\xe7yA\xa1\x87\xf7\xc8\x9c\x9c<M%\xf0V\xa4RL \x10\xca\xae\xeb\xea\xeb\xe9\x0e\xae\xf3\x17.}\xd7F0\x0c\xfb\xe6\xdbu\xa1\x13\xa6\xd5\xd5\xd7wC\x8e\xef\x11\xea\x1cw\x99,V\xe4\x82h}}\xfd\x88\xf0\xb0\x87\x8f\xb2b\x8f\xc6\xb7\xb5n\xd8\xb8\x95 \x88\x85\xf3?Wc\xc4w\xc2\xd9\xc91:j\xc1\xd2\xe5\xabD"\x91\xa6r\xe8\x1c*U\xcb\xc0@_v}\xf5Z\x12\x00\xcc\x8b\x0c\x7f\xa7\x16b\x8f\xc5\xcf\x98\xf5yjj\xfa\xbe?v\xf477\xef\x9e4\xdf\x1b\xd4\xf89\xd8\xbb\xff\x10\xdd\xc15\xe1\xec\x85\xb9\x11\x0b\x1d\x87z%\xdd\xbc#7UU\xd7\x0c\x1a\xe2~#\xe9\xb6\x1a\xc3\xa9\x00\x9b\xcdqq\xf3\xd5\xe0\xd8\xaf$\xcdL\xa6\xa7w\xc0\x96m;T\xab\x9ex\xf6\x82\x93\x8bwjZ\xba\xba\xf3z\xbfP\xa7v\'M\x9dEwp-/\xaf\x10\x89DL\x16\xab\xadi\xe3\xa6m\xa3\x03\xc7J\xa5\x98\x1a\xc3\xa9\xc6\x7f~\xfc\xc5\xd7/P>5\xbf\x87H\xa5X\xe4\xfc\xe8\xcd[~\xebJ#>#\xc6\x0c\xf3\xf2\x97J\xa5\xea\xcb\xeb\xbdCmk\x06>\x9f\xff\xfcy\xa1Y\xaf^vv\xb6\xba\xba\xba\xbdLM\xe5&\x91Ht&\xe1\xdc\xd8\xb1\x9fP\xa9\x9a?\n\x19\x1f\x1a\xd2\xd8\xd8\x94\xf2 M\xd3\x89t\xc8\xfa\r\x9b\x87\xfbz\xafY\xbd\n\x00\xee\xa7\xa4*Y\xeb\xce\xdd\xe4\xaf\xbeY\xcb\xe1pe\xb7\xb66\xd6\x1c\x0e\xb7\xa4\xe4Ewf\xaaa\xd4&\xa6\xdc\xdc|\x1c\xc7\x87\x0eujo\xba{\xef>\x8b\xcd\xf6\xf4pWW\xac\xae\xe0\xee\xe6B\xa5j\xa5\xa6\xa5k:\x11\xc5\x1c\x8f;\xd9\xa7O\xef\xe5\xcb\xa2\x01\x00\xc3\xf0S\xa7\x13\x95\xac\x18\x17\x7f\xfa\xe2\xa5\xaby\xf9\xcfd\xb7L\x16\x8bJ\xa5\xda\xda\xdatg\xb2\x1aF\r\xe7j\x01cB^\xbd\xaa\x93]\xa712\xec\x07\xbbQ(\x94m[6L\x9d2QV\xf8$;\x07\x00:\xd2\xee\x8d\xc7y\t\x0f2_\xb39\xbe\x83\xe91S\xc66qy[\xcf\xde\xa8|\xdd\xe8;\x84\xben\xf6D]m\xa52\x14\xbf(\xae\xfb~\x95\xb8\xac\xc4pd\xd0\x80\xcd\xbb)\xba\xba\xb2r\x01\xe3\xfe\xabo\x97Zl?@\x1b1JVB\xa3\xd1\x06\x0fvHcdt\xbd\xe3\xefD\x1d\x93}\xfc.\xe3nN\x81U_\xb3\x19\xa3|C<]\x0e\xdf|p-3GOG\'fJ\x88\x9f\xd3 \x00`0\x1e\xfe\xbe\xe3\x8fQ\xa3\xfcc\xbeZC\x10\x04\x93\xc9\xb2\xb5\xb1\x96U\xc7\xb9\x9c\xfa\x1fV\xf3\xd3\x92u\xe9\x83,\xb6\xec\xd1\xb1\xb6\x93\x95K\x1b\xea\xab#&\x99N\x9b\x13\x148\xfa\xf5\xeb\x06\xd9\x8b\x9c\x9e\xfe\xb0\xbc\xbc2:j\x81|\xe7\xf7\xcf\xa4\xeb\xcb\x8e\xaa\xea\x9a\xca\xca\xaa\xe8\xa5+\xe8\x0e\xae\x87c\x8fWVVUVV\xb5]i\xcd\x0c\x8btr\xf1VX\xf7\xc8\xad\x07\xebb\x13_5\xb3\x9a\xb9\xfc\xb0M{\x16\xfd~x\xe6\x86\xdd\xcf*_&\xe7\x16\x06\xfek\xe3\xb9\xb4,e\x12\x902\x9b\xcb\'\x04\x08\xb33Yg\xe3\x8b\x9c\xcd\xd9\xe7N\xc8M/W\xcc/r6\xe7?Lk\xeb\xbf"f5\xdd\xc1\x95\xcf\xe7w\xa1\xd3\xefF=\x93\xbd`\xfb\xc1\xbbO\x9f\xb7\x88%\t\x0f\x1e\x05\xae\xd9\xb8ro\xfc\xfa\x93\x97\xd8|\xc1\x97{\x8eO\xfa\xf1w\x99[`p(\xdd\xc1\xb5\xed\xdf\xbe\x03\x87\t\x82 p\xbc\xe6\x8bpf\xdc\x01qeY\x91\xb3\xf9\xab\xb5_\xca[f\x1e\xdf_\xe4l\xde\xb8\xebW\x82 \xe2\xe2O-Z\xbc|\xfa\xcc\xf0\xb1\xe3\xa7\x1e9\x1a\x87\xe3x\x8fuP#\xa8a\x ...

# %%
IDAT_data = zlib.decompress(IDAT_data)

# %%
def PaethPredictor(a, b, c):
    p = a + b - c
    pa = abs(p - a)
    pb = abs(p - b)
    pc = abs(p - c)
    if pa <= pb and pa <= pc:
        Pr = a
    elif pb <= pc:
        Pr = b
    else:
        Pr = c
    return Pr

Recon = []
bytesPerPixel = 4
stride = width * bytesPerPixel

# %%
def Recon_a(r, c):
    return Recon[r * stride + c - bytesPerPixel] if c >= bytesPerPixel else 0

def Recon_b(r, c):
    return Recon[(r-1) * stride + c] if r > 0 else 0

def Recon_c(r, c):
    return Recon[(r-1) * stride + c - bytesPerPixel] if r > 0 and c >= bytesPerPixel else 0

# %%
i = 0
for r in range(height): # for each scanline
    filter_type = IDAT_data[i] # first byte of scanline is filter type
    i += 1
    for c in range(stride): # for each byte in scanline
        Filt_x = IDAT_data[i]
        i += 1
        if filter_type == 0: # None
            Recon_x = Filt_x
        elif filter_type == 1: # Sub
            Recon_x = Filt_x + Recon_a(r, c)
        elif filter_type == 2: # Up
            Recon_x = Filt_x + Recon_b(r, c)
        elif filter_type == 3: # Average
            Recon_x = Filt_x + (Recon_a(r, c) + Recon_b(r, c)) // 2
        elif filter_type == 4: # Paeth
            Recon_x = Filt_x + PaethPredictor(Recon_a(r, c), Recon_b(r, c), Recon_c(r, c))
        # else:
        #     raise Exception('unknown filter type: ' + str(filter_type))
        Recon.append(Recon_x & 0xff) # truncation to byte
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 6
#       4 i += 1
#       5 for c in range(stride): # for each byte in scanline
# ----> 6     Filt_x = IDAT_data[i]
#       7     i += 1
#       8     if filter_type == 0: # None
#
# IndexError: index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(np.array(Recon).reshape((height, width, 4)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 plt.imshow(np.array(Recon).reshape((height, width, 4)))
#       4 plt.show()
#
# NameError: name 'Recon' is not defined
